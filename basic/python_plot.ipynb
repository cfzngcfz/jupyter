# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn
import numpy
plt.close()

# %% [markdown]
# 官网：https://matplotlib.org/stable/index.html
# API：https://matplotlib.org/stable/api/pyplot_summary.html

# %% [markdown]
# # 模板
# ## 线图
# ### 二维

# %%
# 简版
x02 = numpy.linspace(-3, 3, 20) # 闭区间[0,99]等距取100个点
y02 = x02 ** 2

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x02, y02, color="red", linestyle=':', marker='X', label='test')
ax.legend(loc='upper left')

# %%
from matplotlib.font_manager import findfont, FontProperties
path_ttf = findfont(FontProperties(family=FontProperties().get_family()))
print("path of ttf:", path_ttf)
# refer to: https://subaochen.github.io/%E9%AB%98%E6%95%88%E5%B7%A5%E4%BD%9C/2020/03/07/matplotlib-chinese/
chinese_font = FontProperties(fname='/'.join(path_ttf.split('/')[0:-1])+'/msyh.ttf')
# refer to: https://www.cnblogs.com/arkenstone/p/6411055.html

# %%
x01 = list(range(100))
x02 = numpy.linspace(-3, 3, 1000) # 闭区间[0,99]等距取100个点
x03 = numpy.arange(0, 100, 1) # 左闭右开区间 [0, 100)以步长1取点
y01 = [i**2 for i in x01]
y02 = x02 ** 2
x_min, x_max, y_min, y_max = -4, 4, -1, 10

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.plot(x02, y02, 
         color=seaborn.xkcd_rgb['baby poop green'], 
         linestyle=':', linewidth = 1, dashes=(2,1), # 线属性
         # linestyle(ls)可选参数:
         # '-'       solid line style
         # '--'      dashed line style
         # '-.'      dash-dot line style
         # ':'       dotted line style
         # linewidth(lw)：线宽
         # dashes: 虚线比例，划线长与间隔长之比为a/b         
         marker='o', markersize=3, markeredgewidth=1.5, markeredgecolor='r', markerfacecolor='w',  # 点属性
         # markersize(ms)：点大小。
         # markeredgewidth(mew)：点边缘线宽。
         # markeredgecolor(mec)：点边缘颜色。默认与线同色。
         # markerfacecolor(mfc)：点填充颜色。默认与线同色。
         markevery = 50,# 每markevery个点绘制一个点
         label='test')

ax.vlines([1,3], y_min, y_max, colors='blue', linestyles='dashed', label="vlines")
ax.hlines([4,8], x_min, x_max, colors='green', linestyles='dotted', label="hlines")

ax.text(x=0., y=6., s='雅黑',
        ha='right', # horizontalalignment: {'center', 'right', 'left'}
        va='bottom', # verticalalignment: {'center', 'top', 'bottom', 'baseline'}
        color="blue",
        fontsize="large", # float or {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
        fontstyle="italic", # {'normal', 'italic', 'oblique'}
        fontweight='bold', # {'normal', 'bold', 'heavy', 'light', 'ultrabold', 'ultralight']}
        fontproperties=chinese_font, # 指定字体
        rotation=45, # 旋转角度
        # backgroundcolor,
        
       ) # refer to: https://matplotlib.org/stable/tutorials/text/text_props.html


ax.legend(loc='upper center')
# loc 可选'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right',
#         'center left', 'center right', 'lower center', 'upper center', 'center'
ax.set_title(r'Title even support LaTeX: $\alpha\geq\beta$', loc='left', fontsize=20)
ax.set_xlabel('This is a X far from x-axis!', labelpad=20, fontsize=16) # labelpad: xlabel到x轴的距离
ax.set_ylabel('This is a small fontsize Y!', fontsize=12)

ax.axis([x_min, x_max, y_min, y_max])
#ax.set_xlim([x_min, x_max])
#ax.axis(xmax=x_max)
ax.set_xticks([-4,-2,0,2,4]) # 设置刻度
ax.set_xticklabels(['A','B','C','D','E']) # 设置刻度标签
#ax.set_xticks([]) #隐藏横坐标刻度
#ax.set_yticks([]) #隐藏纵坐标刻度

ax.spines['right'].set_visible(False) # 隐藏右边框
ax.spines['top'].set_visible(False) # 隐藏上边框
ax.spines['bottom'].set_position(('data', 1)) # 下边框移至y=1处
ax.spines['left'].set_position(('data', -2)) # 左边框移至x=-2处

#ax.get_xaxis().set_visible(False) # x轴不可见
#ax.get_yaxis().set_visible(False) # y轴不可见
#ax.set_frame_on(False) # 隐藏框架和背景色，set_facecolor功能也被关闭
ax.set_facecolor('pink')

# %%
x21 = numpy.linspace(0, 2*numpy.pi, 1000)
y21 = numpy.sin(x21)

fig = plt.figure(figsize=(15, 6))
ax21 = fig.add_subplot(231)
ax21.plot(x21, y21)
ax21.set_xlabel('X')
ax21.set_ylabel('Y')
ax21.set_title('Default')

ax22 = fig.add_subplot(232)
ax22.plot(x21, y21)
ax22.set_xlabel('X')
ax22.set_ylabel('Y')
ax22.set_title('Default without axes')
ax22.set_axis_off() # 隐藏坐标轴

ax23 = fig.add_subplot(233)
ax23.plot(x21, y21)
ax23.set_xlabel('X')
ax23.set_ylabel('Y')
ax23.set_title('Default without frames')
ax23.set_frame_on(False)

ax24 = fig.add_subplot(234)
ax24.plot(x21, y21)
ax24.set_xlabel('X')
ax24.set_ylabel('Y')
ax24.set_title('Given all boundaries')
ax24.axis([0, 7, -1, 1])

ax25 = fig.add_subplot(235)
ax25.plot(x21, y21)
ax25.set_xlabel('X')
ax25.set_ylabel('Y')
ax25.set_title('Given Xmax only')
ax25.axis(xmax=2*numpy.pi)

ax26 = fig.add_subplot(236)
ax26.plot(x21, y21)
ax26.set_xlabel('X')
ax26.set_ylabel('Y')
ax26.set_title('X-limit with background color')
ax26.set_xlim([1, 5])
ax26.set_facecolor("lightgreen")

fig.subplots_adjust(hspace=0.35, wspace=0.35)
#fig.subplots_adjust(hspace=0, wspace=0)
#subplots_adjust(self, left=None, bottom=None, right=None, top=None,
#                    wspace=None, hspace=None)
#left  = 0.125  # the left side of the subplots of the figure(没搞懂)
#right = 0.9    # the right side of the subplots of the figure(没搞懂)
#bottom = 0.1   # the bottom of the subplots of the figure(没搞懂)
#top = 0.9      # the top of the subplots of the figure(没搞懂)
#wspace = 0.2   # the amount of width reserved for space between subplots,
#               # expressed as a fraction of the average axis width
#hspace = 0.2   # the amount of height reserved for space between subplots,
#               # expressed as a fraction of the average axis height

# %% [markdown]
# ### 三维

# %%
z = numpy.linspace(0, 15, 1000)
x = numpy.sin(z)
y = numpy.cos(z)

fig = plt.figure()
ax0 = fig.add_subplot(111, projection='3d') # 声明3D图

ax0.plot(x, y, z, color='red', linestyle='-.')
# ax0.plot3D(x, y, z, color='red', linestyle='-.')

ax0.set_title("trajectory")
ax0.set_xlabel("x")
ax0.set_ylabel("y")
ax0.set_zlabel("z")

# %% [markdown]
# ## 散点图
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
# ### 二维

# %%
n = 500
x = numpy.random.rand(n)
y = numpy.random.rand(n)
size = numpy.random.rand(n) * 50 # 生成每个点的大小，每个数据点生成控制大小的数组 size
colour = numpy.arctan2(x, y)     # 生成每个点的颜色大小，每个数据点生成控制颜色的数组 colour

fig = plt.figure()
ax0 = fig.add_subplot(111) 

ax0.scatter(x, y, s=size, c=colour, cmap="hsv")

# %% [markdown]
# ### 三维

# %%
n = 200
z = numpy.random.rand(n)
x = numpy.random.rand(n)
y = numpy.random.rand(n)
size = numpy.random.rand(n)*50

fig = plt.figure()
ax0 = fig.add_subplot(111, projection='3d') # 声明3D图

ax0.scatter(x, y, z, s=size, c=x+y+z, cmap="cool")
# ax0.scatter3D(x, y, z, s=size, c=x+y+z, cmap="cool")

ax0.set_xlabel("x")
ax0.set_ylabel("y")
ax0.set_zlabel("z")

# %% [markdown]
# ## 圆 & 球
# ### 二维圆
# $ \begin{cases}
# x = a+r\sin\theta \\
# y=b+r\cos\theta \\
# 0\leq\theta\leq2\pi
# \end{cases} $

# %%
import numpy
import matplotlib.pyplot as plt
a,b = 1,2 #圆心
r = 3     #半径
theta = numpy.linspace(0, 2 * numpy.pi, 200)
x = a + r * numpy.cos(theta)
y = b + r * numpy.sin(theta)

fig = plt.figure(figsize=(3, 3))
ax = fig.add_subplot(111)
ax.plot(x, y, color="red", linewidth=2)
#ax.xaxis.set_major_locator(plt.NullLocator()) # 删除x轴刻度，如需显示x轴刻度注释该行代码即可。
#ax.yaxis.set_major_locator(plt.NullLocator()) # 删除y轴刻度，如需显示y轴刻度注释该行代码即可。

# %% [markdown]
# ### 三维球
# $ \begin{cases}
# x = a+r\sin\phi\cos\theta \\
# y=b+r\sin\phi\sin\theta \\
# z=c+r\cos\phi \\
# 0 \leq \theta \leq 2\pi \\
# 0 \leq \phi \leq \pi
# \end{cases}$

# %%
import numpy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
a,b,c = 1,2,3 #球心
r = 5         #半径
theta = numpy.linspace(0, 2 * numpy.pi, 100)
phi = numpy.linspace(0, numpy.pi, 100)
theta, phi = numpy.meshgrid(theta, phi)
X = a + r*numpy.sin(phi) * numpy.cos(theta)
Y = b + r*numpy.sin(phi) * numpy.sin(theta)
Z = c + r*numpy.cos(phi)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # 声明3D图
ax.plot_surface(X, Y, Z, cmap='rainbow')

# %% [markdown]
# ## 直方图
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=False, facecolor='g', hatch ='*', alpha=0.75)

# hatch: {'/', '\', '|', '-', '+', 'x', 'o', 'O', '.', '*'}
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(50, 600, r'$\mu=100,\ \sigma=15$')
plt.grid(True)

# %%
import matplotlib.pyplot as plt
import numpy
import random

mu_ = 0 # 均值
sigma_ = 1 # 标准差
n = 10000 # 样本数


list_gauss = [random.gauss(mu=mu_,sigma=sigma_) for _ in range(n)]
list_normal = [random.normalvariate(mu=mu_,sigma=sigma_) for _ in range(n)]

x = numpy.linspace(-10, 10, 100)


fig = plt.figure(figsize=(20, 6))
ax0 = fig.add_subplot(121) 
ax0.hist(list_gauss, bins=100, density=True, facecolor="pink", edgecolor="green")#指定刻度的范围，以及步长

x = numpy.linspace(-4, 4, 100)
ax0.plot(x, 1 / numpy.sqrt(2*numpy.pi)/sigma_ * numpy.exp(-(x-mu_)**2/2/sigma_**2), linewidth=4)


ax1 = fig.add_subplot(122) 
ax1.hist(list_normal, bins=100, density=True, facecolor="blue", edgecolor="yellow")#指定刻度的范围，以及步长
ax1.plot(x, 1 / numpy.sqrt(2*numpy.pi)/sigma_ * numpy.exp(-(x-mu_)**2/2/sigma_**2), linewidth=4)

# %% [markdown]
# ## 柱状图
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.barh.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据
solve_cost_LM = [45.6277, 115.21, 133.864, 155.735]
makeHessian_cost_LM = [30.3227, 93.4366, 113.693, 136.583]
solve_cost_dog_leg = [38.7251, 41.9409, 49.0348, 57.0279]
makeHessian_cost_dog_leg = [23.998, 32.2293, 40.3307, 46.6025]
nums = len(solve_cost_LM)


bar_width = 0.2

fig = plt.figure(figsize=(20, 6))
#fig = plt.figure(figsize=(20, 6))
ax0 = fig.add_subplot(121)
ax0.bar([ii-bar_width/2 for ii in range(len(solve_cost_LM))], height=solve_cost_LM,
        width=bar_width, bottom=None, align="center", color="red", alpha=0.5, hatch='o', label="LM")
ax0.bar([ii+bar_width/2 for ii in range(len(solve_cost_LM))], height=solve_cost_dog_leg,
        width=bar_width, bottom=None, align="center", color="green", alpha=0.5, hatch='*', label="Dog-leg")
# align="center": bar的中心与x位置对齐
# align="edge": bar的左边缘与x位置对齐
for ii in range(len(solve_cost_LM)):
    ax0.text(ii-bar_width/2, solve_cost_LM[ii], str(solve_cost_LM[ii]), ha='right', va='bottom',
             fontsize="large",
             # fontsize: float or {'xx-small', 'x-small', 'small', 'medium', 'large', 'x-large', 'xx-large'}
             rotation=45, # 旋转角度
            )
    ax0.text(ii+bar_width/2, solve_cost_dog_leg[ii], str(solve_cost_dog_leg[ii]), ha='left', va='bottom', fontsize="large", rotation=-45)
ax0.set_title("solve cost", loc='left', fontsize="xx-large")
ax0.set_xticks([ii for ii in range(nums)]) # 设置刻度
ax0.set_xticklabels(["non-acceleration", "3 threads", "6 threads", "9 threads"]) # 设置刻度标签
ax0.legend(loc='upper left')


ax1 = fig.add_subplot(122)
ax1.bar([ii-bar_width/2 for ii in range(len(solve_cost_LM))], height=makeHessian_cost_LM,
        width=bar_width, bottom=None, align="center", color="blue", alpha=0.5, hatch='o', label="LM")
ax1.bar([ii+bar_width/2 for ii in range(len(solve_cost_LM))], height=makeHessian_cost_dog_leg,
        width=bar_width, bottom=None, align="center", color="orange", alpha=0.5, hatch='*', label="Dog-leg")
for ii in range(len(solve_cost_LM)):
    ax1.text(ii-bar_width/2, makeHessian_cost_LM[ii], str(makeHessian_cost_LM[ii]), ha='right', va='bottom', fontsize="large")
    ax1.text(ii+bar_width/2, makeHessian_cost_dog_leg[ii], str(makeHessian_cost_dog_leg[ii]), ha='left', va='bottom', fontsize="large")
ax1.set_title("makeHessian cost", loc='center', fontsize="xx-large")
ax1.set_xticks([ii for ii in range(nums)]) # 设置刻度
ax1.set_xticklabels(["non-acceleration", "3 threads", "6 threads", "9 threads"]) # 设置刻度标签
ax1.legend(loc='upper left')

# %% [markdown]
# ## 三维图

# %%
def f(x, y):
    return numpy.sin(numpy.sqrt(x ** 2 + y ** 2))
x = numpy.linspace(-6,6,30)
y = numpy.linspace(-6,6,30)
X, Y = numpy.meshgrid(x, y)
Z = f(X,Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
#调整观察角度和方位角。这里将俯仰角设为60度，把方位角调整为35度
ax.view_init(60, 35)

# %%
fig =plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='c')
ax.set_title('wireframe')

# %%
#曲面图
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_title('surface')

# %%
#使用极坐标可以获得切片的效果
r = numpy.linspace(0, 6, 20)
theta = numpy.linspace(-0.9 * numpy.pi, 0.8 * numpy.pi, 40)
r, theta = numpy.meshgrid(r, theta)
X = r * numpy.sin(theta)
Y = r * numpy.cos(theta)
Z = f(X, Y)
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')

# %%
# 曲面三角剖分
theta = 2 * numpy.pi * numpy.random.random(1000)
r = 6 * numpy.random.random(1000)
x = numpy.ravel(r * numpy.sin(theta))
y = numpy.ravel(r * numpy.cos(theta))
z = f(x, y)

ax = plt.axes(projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5)

# %%
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', edgecolor='none')

# %%
#绘制莫比乌斯带
#由于它是一条二维带，因此需要两个内在维度。theta维度取值范围是0～2pi，宽度维度w取值范围是-1～1
theta = numpy.linspace(0, 2 * numpy.pi, 30)
w = numpy.linspace(-0.25, 0.25, 8)
w, theta = numpy.meshgrid(w, theta)
phi = 0.5 * theta
#x-y平面内的半径
r = 1 + w * numpy.cos(phi)

x = numpy.ravel(r * numpy.cos(theta))
y = numpy.ravel(r * numpy.sin(theta))
z = numpy.ravel(w * numpy.sin(phi))

#要画出莫比乌斯带，还必须保证三角部分是正确的。最好的方法是首先用基本参数化方法定义三角部分，然后用Matplotlib将
#这个三角剖分映射到莫比乌斯带的三维空间里
from matplotlib.tri import Triangulation
tri = Triangulation(numpy.ravel(w), numpy.ravel(theta))
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap='viridis', linewidth=0.2)
ax.set_xlim(-1, 1);ax.set_ylim(-1,1);ax.set_zlim(-1,1)

# %% [markdown]
# # 图片保存/savefig
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html#matplotlib.pyplot.savefig

# %%
#fig.savefig('./temp/fig.png', bbox_inches='tight', transparent='True', dpi=200)

# bbox_inches='tight' 减少图片周围的空白区域
# transparent=True    图片背景透明
# dpi                 分辨率

支持的格式包括：.eps, .jpeg, .jpg, .pdf, .pgf, .png, .ps, .raw, .rgba, .svg, .svgz, .tif, .tiff

# %% [markdown]
# # 参数
# ## marker
#
# char|marker
# -|-
# '.' | point marker
# ',' | pixel marker
# 'o' | circle marker
# 'v' | triangle_down marker
# '^' | triangle_up marker
# '<' | triangle_left marker
# '>' | triangle_right marker
# '1' | tri_down marker
# '2' | tri_up marker
# '3' | tri_left marker
# '4' | tri_right marker
# '8' | octagon marker
# 's' | square marker
# 'p' | pentagon marker
# 'P' | plus (filled) marker
# '*' | star marker
# 'h' | hexagon1 marker
# 'H' | hexagon2 marker
# '+' | plus marker
# 'x' | x marker
# 'X' | x (filled) marker
# 'D' | diamond marker
# 'd' | thin_diamond marker
# '\|' | vline marker
# '_' | hline marker

# %% [markdown]
# ![0.markers.png](attachment:0.markers.png)

# %% [markdown]
# ##  color
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html
# https://www.5tu.cn/colors/yansezhongwenming.html
# https://xw.qq.com/cmsid/20200413a0433m00

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
        print(names)
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        swatch_end_x = cell_width * col + swatch_width
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.hlines(y, swatch_start_x, swatch_end_x,
                  color=colors[name], linewidth=18)

# plot_colortable(mcolors.BASE_COLORS, "Base Colors",
#                sort_colors=False, emptycols=1)
# plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
#                sort_colors=False, emptycols=2)

#sphinx_gallery_thumbnail_number = 3
plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# Optionally plot the XKCD colors (Caution: will produce large figure)
#xkcd_fig = plot_colortable(mcolors.XKCD_COLORS, "XKCD Colors")
#xkcd_fig.savefig("XKCD_Colors.png")

# %% [markdown]
# ![0.seaborn.xkcd_rgb.jpg](attachment:0.seaborn.xkcd_rgb.jpg)

# %%
#X11色卡
colors = [("LightPink", "#FFB6C1"),("Pink", "#FFC0CB"),("Crimson", "#DC143C"),("LavenderBlush", "#FFF0F5"),
          ("PaleVioletRed", "#DB7093"),("HotPink", "#FF69B4"),("DeepPink", "#FF1493"),("MediumVioletRed", "#C71585"),        
          ("Orchid", "#DA70D6"),("Thistle", "#D8BFD8"),("Plum", "#DDA0DD"),("Violet", "#EE82EE"),                            
          ("Magenta", "#FF00FF"),("Fuchsia", "#FF00FF"),("DarkMagenta", "#8B008B"),("Purple", "#800080"),                    
          ("MediumOrchid", "#BA55D3"),("DarkViolet", "#9400D3"),("DarkOrchid", "#9932CC"),("Indigo", "#4B0082"),             
          ("BlueViolet", "#8A2BE2"),("MediumPurple", "#9370DB"),("MediumSlateBlue", "#7B68EE"),("SlateBlue", "#6A5ACD"),     
          ("DarkSlateBlue", "#483D8B"),("Lavender", "#E6E6FA"),("GhostWhite", "#F8F8FF"),("Blue", "#0000FF"),                
          ("MediumBlue", "#0000CD"),("MidnightBlue", "#191970"),("DarkBlue", "#00008B"),("Navy", "#000080"),                 
          ("RoyalBlue", "#4169E1"),("CornflowerBlue", "#6495ED"),("LightSteelBlue", "#B0C4DE"),("LightSlateGray", "#778899"),
          ("SlateGray", "#708090"),("DodgerBlue", "#1E90FF"),("AliceBlue", "#F0F8FF"),("SteelBlue", "#4682B4"),              
          ("LightSkyBlue", "#87CEFA"),("SkyBlue", "#87CEEB"),("DeepSkyBlue", "#00BFFF"),("LightBlue", "#ADD8E6"),            
          ("PowderBlue", "#B0E0E6"),("CadetBlue", "#5F9EA0"),("Azure", "#F0FFFF"),("LightCyan", "#E0FFFF"),                  
          ("PaleTurquoise", "#AFEEEE"),("Cyan", "#00FFFF"),("Aqua", "#00FFFF"),("DarkTurquoise", "#00CED1"),                 
          ("DarkSlateGray", "#2F4F4F"),("DarkCyan", "#008B8B"),("Teal", "#008080"),("MediumTurquoise", "#48D1CC"),           
          ("LightSeaGreen", "#20B2AA"),("Turquoise", "#40E0D0"),("Aquamarine", "#7FFFD4"),("MediumAquamarine", "#66CDAA"),   
          ("MediumSpringGreen", "#00FA9A"),("MintCream", "#F5FFFA"),("SpringGreen", "#00FF7F"),("MediumSeaGreen", "#3CB371"),
          ("SeaGreen", "#2E8B57"),("Honeydew", "#F0FFF0"),("LightGreen", "#90EE90"),("PaleGreen", "#98FB98"),                
          ("DarkSeaGreen", "#8FBC8F"),("LimeGreen", "#32CD32"),("Lime", "#00FF00"),("ForestGreen", "#228B22"),               
          ("Green", "#008000"),("DarkGreen", "#006400"),("Chartreuse", "#7FFF00"),("LawnGreen", "#7CFC00"),                  
          ("GreenYellow", "#ADFF2F"),("DarkOliveGreen", "#556B2F"),("YellowGreen", "#9ACD32"),("OliveDrab", "#6B8E23"),      
          ("Beige", "#F5F5DC"),("LightGoldenrodYellow", "#FAFAD2"),("Ivory", "#FFFFF0"),("LightYellow", "#FFFFE0"),          
          ("Yellow", "#FFFF00"),("Olive", "#808000"),("DarkKhaki", "#BDB76B"),("LemonChiffon", "#FFFACD"),                   
          ("PaleGoldenrod", "#EEE8AA"),("Khaki", "#F0E68C"),("Gold", "#FFD700"),("Cornsilk", "#FFF8DC"),                     
          ("Goldenrod", "#DAA520"),("DarkGoldenrod", "#B8860B"),("FloralWhite", "#FFFAF0"),("OldLace", "#FDF5E6"),           
          ("Wheat", "#F5DEB3"),("Moccasin", "#FFE4B5"),("Orange", "#FFA500"),("PapayaWhip", "#FFEFD5"),                      
          ("BlanchedAlmond", "#FFEBCD"),("NavajoWhite", "#FFDEAD"),("AntiqueWhite", "#FAEBD7"),("Tan", "#D2B48C"),           
          ("BurlyWood", "#DEB887"),("Bisque", "#FFE4C4"),("DarkOrange", "#FF8C00"),("Linen", "#FAF0E6"),                     
          ("Peru", "#CD853F"),("PeachPuff", "#FFDAB9"),("SandyBrown", "#F4A460"),("Chocolate", "#D2691E"),                   
          ("SaddleBrown", "#8B4513"),("Seashell", "#FFF5EE"),("Sienna", "#A0522D"),("LightSalmon", "#FFA07A"),               
          ("Coral", "#FF7F50"),("OrangeRed", "#FF4500"),("DarkSalmon", "#E9967A"),("Tomato", "#FF6347"),                     
          ("MistyRose", "#FFE4E1"),("Salmon", "#FA8072"),("Snow", "#FFFAFA"),("LightCoral", "#F08080"),                      
          ("RosyBrown", "#BC8F8F"),("IndianRed", "#CD5C5C"),("Red", "#FF0000"),("Brown", "#A52A2A"),                         
          ("FireBrick", "#B22222"),("DarkRed", "#8B0000"),("Maroon", "#800000"),("White", "#FFFFFF"),                        
          ("WhiteSmoke", "#F5F5F5"),("Gainsboro", "#DCDCDC"),("LightGray", "#D3D3D3"),("Silver", "#C0C0C0"),                 
          ("DarkGray", "#A9A9A9"),("Gray", "#808080"),("DimGray", "#696969"),("Black", "#000000")]       

fig = plt.figure(figsize=(15, 12))
ax2 = fig.add_subplot(111)
cols = 4
box_width, box_height, colpad, rowpad = 10, 4, 9, 2
for ii in range(len(colors)):
    curname = colors[ii][0]
    num_col, num_row = divmod(ii, len(colors)/cols)
    ax2.fill_between([box_width*num_col, box_width*(num_col+1)-colpad], # 横坐标的范围
                    [box_height*num_row, box_height*num_row], # 纵坐标下界
                    [box_height*(num_row+1)-rowpad, box_height*(num_row+1)-rowpad], # 纵坐标上界
                    facecolor=curname)
    ax2.text(box_width*(num_col+1)-0.95*colpad, box_height*num_row+(box_height-rowpad)/2,
            ', '.join([colors[ii][0],colors[ii][1]]), #文本内容
            horizontalalignment="left", verticalalignment='center')
ax2.set_axis_off() # 隐藏坐标轴
#Axes-轴域；Axis-轴
ax2.set_title("X11 colors table", fontsize=16)

# %%
colors = [("LightPink", "#FFB6C1"),("Pink", "#FFC0CB"),("Crimson", "#DC143C"),("LavenderBlush", "#FFF0F5"),
          ("PaleVioletRed", "#DB7093"),("HotPink", "#FF69B4"),("DeepPink", "#FF1493"),("MediumVioletRed", "#C71585"),        
          ("Orchid", "#DA70D6"),("Thistle", "#D8BFD8"),("Plum", "#DDA0DD"),("Violet", "#EE82EE"),                            
          ("Magenta", "#FF00FF"),("Fuchsia", "#FF00FF"),("DarkMagenta", "#8B008B"),("Purple", "#800080"),                    
          ("MediumOrchid", "#BA55D3"),("DarkViolet", "#9400D3"),("DarkOrchid", "#9932CC"),("Indigo", "#4B0082"),             
          ("BlueViolet", "#8A2BE2"),("MediumPurple", "#9370DB"),("MediumSlateBlue", "#7B68EE"),("SlateBlue", "#6A5ACD"),     
          ("DarkSlateBlue", "#483D8B"),("Lavender", "#E6E6FA"),("GhostWhite", "#F8F8FF"),("Blue", "#0000FF"),                
          ("MediumBlue", "#0000CD"),("MidnightBlue", "#191970"),("DarkBlue", "#00008B"),("Navy", "#000080"),                 
          ("RoyalBlue", "#4169E1"),("CornflowerBlue", "#6495ED"),("LightSteelBlue", "#B0C4DE"),("LightSlateGray", "#778899"),
          ("SlateGray", "#708090"),("DodgerBlue", "#1E90FF"),("AliceBlue", "#F0F8FF"),("SteelBlue", "#4682B4"),              
          ("LightSkyBlue", "#87CEFA"),("SkyBlue", "#87CEEB"),("DeepSkyBlue", "#00BFFF"),("LightBlue", "#ADD8E6"),            
          ("PowderBlue", "#B0E0E6"),("CadetBlue", "#5F9EA0"),("Azure", "#F0FFFF"),("LightCyan", "#E0FFFF"),                  
          ("PaleTurquoise", "#AFEEEE"),("Cyan", "#00FFFF"),("Aqua", "#00FFFF"),("DarkTurquoise", "#00CED1"),                 
          ("DarkSlateGray", "#2F4F4F"),("DarkCyan", "#008B8B"),("Teal", "#008080"),("MediumTurquoise", "#48D1CC"),           
          ("LightSeaGreen", "#20B2AA"),("Turquoise", "#40E0D0"),("Aquamarine", "#7FFFD4"),("MediumAquamarine", "#66CDAA"),   
          ("MediumSpringGreen", "#00FA9A"),("MintCream", "#F5FFFA"),("SpringGreen", "#00FF7F"),("MediumSeaGreen", "#3CB371"),
          ("SeaGreen", "#2E8B57"),("Honeydew", "#F0FFF0"),("LightGreen", "#90EE90"),("PaleGreen", "#98FB98"),                
          ("DarkSeaGreen", "#8FBC8F"),("LimeGreen", "#32CD32"),("Lime", "#00FF00"),("ForestGreen", "#228B22"),               
          ("Green", "#008000"),("DarkGreen", "#006400"),("Chartreuse", "#7FFF00"),("LawnGreen", "#7CFC00"),                  
          ("GreenYellow", "#ADFF2F"),("DarkOliveGreen", "#556B2F"),("YellowGreen", "#9ACD32"),("OliveDrab", "#6B8E23"),      
          ("Beige", "#F5F5DC"),("LightGoldenrodYellow", "#FAFAD2"),("Ivory", "#FFFFF0"),("LightYellow", "#FFFFE0"),          
          ("Yellow", "#FFFF00"),("Olive", "#808000"),("DarkKhaki", "#BDB76B"),("LemonChiffon", "#FFFACD"),                   
          ("PaleGoldenrod", "#EEE8AA"),("Khaki", "#F0E68C"),("Gold", "#FFD700"),("Cornsilk", "#FFF8DC"),                     
          ("Goldenrod", "#DAA520"),("DarkGoldenrod", "#B8860B"),("FloralWhite", "#FFFAF0"),("OldLace", "#FDF5E6"),           
          ("Wheat", "#F5DEB3"),("Moccasin", "#FFE4B5"),("Orange", "#FFA500"),("PapayaWhip", "#FFEFD5"),                      
          ("BlanchedAlmond", "#FFEBCD"),("NavajoWhite", "#FFDEAD"),("AntiqueWhite", "#FAEBD7"),("Tan", "#D2B48C"),           
          ("BurlyWood", "#DEB887"),("Bisque", "#FFE4C4"),("DarkOrange", "#FF8C00"),("Linen", "#FAF0E6"),                     
          ("Peru", "#CD853F"),("PeachPuff", "#FFDAB9"),("SandyBrown", "#F4A460"),("Chocolate", "#D2691E"),                   
          ("SaddleBrown", "#8B4513"),("Seashell", "#FFF5EE"),("Sienna", "#A0522D"),("LightSalmon", "#FFA07A"),               
          ("Coral", "#FF7F50"),("OrangeRed", "#FF4500"),("DarkSalmon", "#E9967A"),("Tomato", "#FF6347"),                     
          ("MistyRose", "#FFE4E1"),("Salmon", "#FA8072"),("Snow", "#FFFAFA"),("LightCoral", "#F08080"),                      
          ("RosyBrown", "#BC8F8F"),("IndianRed", "#CD5C5C"),("Red", "#FF0000"),("Brown", "#A52A2A"),                         
          ("FireBrick", "#B22222"),("DarkRed", "#8B0000"),("Maroon", "#800000"),("White", "#FFFFFF"),                        
          ("WhiteSmoke", "#F5F5F5"),("Gainsboro", "#DCDCDC"),("LightGray", "#D3D3D3"),("Silver", "#C0C0C0"),                 
          ("DarkGray", "#A9A9A9"),("Gray", "#808080"),("DimGray", "#696969"),("Black", "#000000")]       

cnames = {
'aliceblue':            '#F0F8FF',
'antiquewhite':         '#FAEBD7',
'aqua':                 '#00FFFF',
'aquamarine':           '#7FFFD4',
'azure':                '#F0FFFF',
'beige':                '#F5F5DC',
'bisque':               '#FFE4C4',
'black':                '#000000',
'blanchedalmond':       '#FFEBCD',
'blue':                 '#0000FF',
'blueviolet':           '#8A2BE2',
'brown':                '#A52A2A',
'burlywood':            '#DEB887',
'cadetblue':            '#5F9EA0',
'chartreuse':           '#7FFF00',
'chocolate':            '#D2691E',
'coral':                '#FF7F50',
'cornflowerblue':       '#6495ED',
'cornsilk':             '#FFF8DC',
'crimson':              '#DC143C',
'cyan':                 '#00FFFF',
'darkblue':             '#00008B',
'darkcyan':             '#008B8B',
'darkgoldenrod':        '#B8860B',
'darkgray':             '#A9A9A9',
'darkgreen':            '#006400',
'darkkhaki':            '#BDB76B',
'darkmagenta':          '#8B008B',
'darkolivegreen':       '#556B2F',
'darkorange':           '#FF8C00',
'darkorchid':           '#9932CC',
'darkred':              '#8B0000',
'darksalmon':           '#E9967A',
'darkseagreen':         '#8FBC8F',
'darkslateblue':        '#483D8B',
'darkslategray':        '#2F4F4F',
'darkturquoise':        '#00CED1',
'darkviolet':           '#9400D3',
'deeppink':             '#FF1493',
'deepskyblue':          '#00BFFF',
'dimgray':              '#696969',
'dodgerblue':           '#1E90FF',
'firebrick':            '#B22222',
'floralwhite':          '#FFFAF0',
'forestgreen':          '#228B22',
'fuchsia':              '#FF00FF',
'gainsboro':            '#DCDCDC',
'ghostwhite':           '#F8F8FF',
'gold':                 '#FFD700',
'goldenrod':            '#DAA520',
'gray':                 '#808080',
'green':                '#008000',
'greenyellow':          '#ADFF2F',
'honeydew':             '#F0FFF0',
'hotpink':              '#FF69B4',
'indianred':            '#CD5C5C',
'indigo':               '#4B0082',
'ivory':                '#FFFFF0',
'khaki':                '#F0E68C',
'lavender':             '#E6E6FA',
'lavenderblush':        '#FFF0F5',
'lawngreen':            '#7CFC00',
'lemonchiffon':         '#FFFACD',
'lightblue':            '#ADD8E6',
'lightcoral':           '#F08080',
'lightcyan':            '#E0FFFF',
'lightgoldenrodyellow': '#FAFAD2',
'lightgreen':           '#90EE90',
'lightgray':            '#D3D3D3',
'lightpink':            '#FFB6C1',
'lightsalmon':          '#FFA07A',
'lightseagreen':        '#20B2AA',
'lightskyblue':         '#87CEFA',
'lightslategray':       '#778899',
'lightsteelblue':       '#B0C4DE',
'lightyellow':          '#FFFFE0',
'lime':                 '#00FF00',
'limegreen':            '#32CD32',
'linen':                '#FAF0E6',
'magenta':              '#FF00FF',
'maroon':               '#800000',
'mediumaquamarine':     '#66CDAA',
'mediumblue':           '#0000CD',
'mediumorchid':         '#BA55D3',
'mediumpurple':         '#9370DB',
'mediumseagreen':       '#3CB371',
'mediumslateblue':      '#7B68EE',
'mediumspringgreen':    '#00FA9A',
'mediumturquoise':      '#48D1CC',
'mediumvioletred':      '#C71585',
'midnightblue':         '#191970',
'mintcream':            '#F5FFFA',
'mistyrose':            '#FFE4E1',
'moccasin':             '#FFE4B5',
'navajowhite':          '#FFDEAD',
'navy':                 '#000080',
'oldlace':              '#FDF5E6',
'olive':                '#808000',
'olivedrab':            '#6B8E23',
'orange':               '#FFA500',
'orangered':            '#FF4500',
'orchid':               '#DA70D6',
'palegoldenrod':        '#EEE8AA',
'palegreen':            '#98FB98',
'paleturquoise':        '#AFEEEE',
'palevioletred':        '#DB7093',
'papayawhip':           '#FFEFD5',
'peachpuff':            '#FFDAB9',
'peru':                 '#CD853F',
'pink':                 '#FFC0CB',
'plum':                 '#DDA0DD',
'powderblue':           '#B0E0E6',
'purple':               '#800080',
'red':                  '#FF0000',
'rosybrown':            '#BC8F8F',
'royalblue':            '#4169E1',
'saddlebrown':          '#8B4513',
'salmon':               '#FA8072',
'sandybrown':           '#F4A460',
#'sandybrown':           '#FAA460',
'seagreen':             '#2E8B57',
'seashell':             '#FFF5EE',
'sienna':               '#A0522D',
'silver':               '#C0C0C0',
'skyblue':              '#87CEEB',
'slateblue':            '#6A5ACD',
'slategray':            '#708090',
'snow':                 '#FFFAFA',
'springgreen':          '#00FF7F',
'steelblue':            '#4682B4',
'tan':                  '#D2B48C',
'teal':                 '#008080',
'thistle':              '#D8BFD8',
'tomato':               '#FF6347',
'turquoise':            '#40E0D0',
'violet':               '#EE82EE',
'wheat':                '#F5DEB3',
'white':                '#FFFFFF',
'whitesmoke':           '#F5F5F5',
'yellow':               '#FFFF00',
'yellowgreen':          '#9ACD32'}

#colors修改记录 'LightGrey' -> 'LightGray'
#cnames修改记录 'sandybrown' = '#f4a460'

def analysis_dict_keys(keys_dict):
    keys_list = []
    for ii in range(len(keys_dict)):
        keys_list.append( str(keys_dict).split("'")[2*ii+1] )
    return keys_list

list_cnames = analysis_dict_keys(cnames.keys())
list_cnames.sort()
colors.sort()

for ii in range(140):
    if colors[ii][0].lower() != list_cnames[ii]:
        print([ii, colors[ii][0].lower(), list_cnames[ii]])

for ii in range(140):
    if cnames.get(list_cnames[ii]) != colors[ii][1]:
        print([ii, cnames.get(list_cnames[ii]), colors[ii][1]])

# %% [markdown]
# ## cmap
# https://matplotlib.org/2.0.2/users/colormaps.html

# %%
"""
==================
Colormap reference
==================

Reference for colormaps included with Matplotlib.

This reference example shows all colormaps included with Matplotlib. Note that
any colormap listed here can be reversed by appending "_r" (e.g., "pink_r").
These colormaps are divided into the following categories:

Sequential:
    These colormaps are approximately monochromatic colormaps varying smoothly
    between two color tones---usually from low saturation (e.g. white) to high
    saturation (e.g. a bright blue). Sequential colormaps are ideal for
    representing most scientific data since they show a clear progression from
    low-to-high values.

Diverging:
    These colormaps have a median value (usually light in color) and vary
    smoothly to two different color tones at high and low values. Diverging
    colormaps are ideal when your data has a median value that is significant
    (e.g.  0, such that positive and negative values are represented by
    different colors of the colormap).

Qualitative:
    These colormaps vary rapidly in color. Qualitative colormaps are useful for
    choosing a set of discrete colors. For example::

        color_list = plt.cm.Set3(np.linspace(0, 1, 12))

    gives a list of RGB colors that are good for plotting a series of lines on
    a dark background.

Miscellaneous:
    Colormaps that don't fit into the categories above.

"""
import numpy as np
import matplotlib.pyplot as plt


# Have colormaps separated into categories:
# http://matplotlib.org/examples/color/colormaps_reference.html
cmaps = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg', 'hsv',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar'])]


nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps)
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps:
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %% [markdown]
# ### 从cmap中取一个颜色

# %%
import matplotlib.pyplot as plt
cmap=plt.get_cmap("Set1")
for ii in range(10):
    rgba = cmap(ii)
    print(ii, rgba)

# %%
import matplotlib.pyplot as plt
cmap=plt.get_cmap("jet")
num = 10
for ii in range(num):
    rgba = cmap(ii/(num-1))
    print(ii, rgba)

# %% [markdown]
# # 内存占用

# %% [markdown]
# command | description
# :-|:-
# plt.cla() | Clear the current axes
# plt.clf() <br> <=> fig.clf() | Clear the current figure. 窗口保持打开状态，以便重复绘图
# plt.close() | Close a figure window. 关闭当前窗口
# plt.close(fig) <br> <=> fig.close() | 关闭指定对象窗口

# %% [markdown]
# ## psutil
# https://psutil.readthedocs.io/en/latest/#psutil.Process.memory_full_info

# %%
import os, psutil
pid = os.getpid()
process = psutil.Process(pid)
process.memory_full_info()

# %% [markdown]
# key | description
# :-|:-
# rss | aka “Resident Set Size”, this is the non-swapped physical memory a process has used. On UNIX it matches “top“‘s RES column). On Windows this is an alias for wset field and it matches “Mem Usage” column of taskmgr.exe.<br>进程使用的非交换物理内存
# vms | aka “Virtual Memory Size”, this is the total amount of virtual memory used by the process. On UNIX it matches “top“‘s VIRT column. On Windows this is an alias for pagefile field and it matches “Mem Usage” “VM Size” column of taskmgr.exe.<br>又名“虚拟内存大小”，这是进程使用的虚拟内存总量
# shared | (Linux) memory that could be potentially shared with other processes. This matches “top“‘s SHR column).<br>与其他进程共享的内存
# text (Linux, BSD) | aka TRS (text resident set) the amount of memory devoted to executable code. This matches “top“‘s CODE column).<br>专用于可执行代码的内存量
# data (Linux, BSD) | aka DRS (data resident set) the amount of physical memory devoted to other than executable code. It matches “top“‘s DATA column).<br>除可执行代码之外的物理内存量
# lib (Linux) | the memory used by shared libraries.<br>共享库使用的内存
# <font color="red">uss</font> (Linux, macOS, Windows) | aka “Unique Set Size”, this is the memory which is unique to a process and which would be freed if the process was terminated right now.<br>进程独有的内存，如果进程立即终止，它将被释放
# pss (Linux) | aka “Proportional Set Size”, is the amount of memory shared with other processes, accounted in a way that the amount is divided evenly between the processes that share it. I.e. if a process has 10 MBs all to itself and 10 MBs shared with another process its PSS will be 15 MBs.<br>与其他进程共享的内存量，其计算方式是在共享它的进程之间平均分配内存量。如果一个进程本身有 10 MB，并且与另一个进程共享 10 MB，则其 PSS 将为 15 MB

# %%
process.memory_percent()

# %% [markdown]
# ## bad case: fig = plt.figure() -> plt.close(fig) in each loop
# plt.close(fig)未清理内存，不断累加会导致<font color="red">内存溢出</font>

# %%
reset

# %%
import os, psutil, numpy, gc
import matplotlib.pyplot as plt

def computing_memory():
    pid = os.getpid()
    process = psutil.Process(pid)
    info = process.memory_full_info()
    print("used memory:", info.uss/(2**20), "MB")
    return info.uss/(2**20)

for index in range(3):
    print("-------------------")
    text = "starting in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

    base = 10
    fig = plt.figure(figsize = (base*16, base*8))
    text = "after fig=plt.figure() in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

    ax = fig.add_subplot(111)
    # plot
    x_seq = numpy.linspace(-10, 10, 10**7)
    y_seq = x_seq ** 2
    ax.plot(x_seq, y_seq, color="red", linestyle=':', marker='X', label='test')
    ax.legend(loc='upper left')

    text = "after plot in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

    plt.close(fig)
    text = "after plt.close(fig) in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

# %% [markdown]
# ## 改进1: fig = plt.figure() -> plt.close(fig) -> gc.collect() in each loop
# 在jupyter中, gc.collect()仅在第一次循环中清理内存, 后续不断累加会导致<font color="red">内存溢出</font>
# 在spyder中, gc.collect()在每次循环中均清理内存

# %%
reset

# %%
import os, psutil, numpy, gc
import matplotlib.pyplot as plt

def computing_memory():
    pid = os.getpid()
    process = psutil.Process(pid)
    info = process.memory_full_info()
    print("used memory:", info.uss/(2**20), "MB")
    return info.uss/(2**20)

for index in range(3):
    print("-------------------")
    text = "starting in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

    base = 10
    fig = plt.figure(figsize = (base*16, base*9))
    text = "after fig=plt.figure() in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

    ax = fig.add_subplot(111)
    # plot
    x_seq = numpy.linspace(-10, 10, 10**7)
    y_seq = x_seq ** 2
    ax.plot(x_seq, y_seq, color="red", linestyle=':', marker='X', label='test')
    ax.legend(loc='upper left')

    text = "after plot in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

    plt.close(fig)
    text = "after plt.close(fig) in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()
    
    gc.collect()
    text = "after gc.collect() in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

# %% [markdown]
# output in spyder
# <code>
#
# -------------------
#
# starting in loop 0
# used memory: 1307.52734375 MB
#
# after fig=plt.figure() in loop 0
# used memory: 1307.52734375 MB
#
# after plot in loop 0
# used memory: 1765.3125 MB
#
# after plt.close(fig) in loop 0
# used memory: 1765.3125 MB
#
# after gc.collect() in loop 0
# used memory: 605.62890625 MB
# -------------------
#
# starting in loop 1
# used memory: 605.6328125 MB
#
# after fig=plt.figure() in loop 1
# used memory: 605.6328125 MB
#
# after plot in loop 1
# used memory: 1063.40625 MB
#
# after plt.close(fig) in loop 1
# used memory: 1063.40625 MB
#
# after gc.collect() in loop 1
# used memory: 605.6328125 MB
# -------------------
#
# starting in loop 2
# used memory: 605.6328125 MB
#
# after fig=plt.figure() in loop 2
# used memory: 605.6328125 MB
#
# after plot in loop 2
# used memory: 1063.40625 MB
#
# after plt.close(fig) in loop 2
# used memory: 1063.40625 MB
#
# after gc.collect() in loop 2
# used memory: 605.6328125 MB
# </code>

# %% [markdown]
# ## 改进2: fig = plt.figure() is outside the loop, and fig.clf() in each loop

# %%
reset

# %%
import os, psutil, numpy, gc
import matplotlib.pyplot as plt

def computing_memory():
    pid = os.getpid()
    process = psutil.Process(pid)
    info = process.memory_full_info()
    print("used memory:", info.uss/(2**20), "MB")
    return info.uss/(2**20)

base = 10
fig = plt.figure(figsize = (base*16, base*9))
for index in range(100):
    print("-------------------")
    text = "starting in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()
    
    ax = fig.add_subplot(111)
    # plot
    x02 = numpy.linspace(-10, 10, 10**7)
    y02 = x02 ** 2
    ax.plot(x02, y02,color="red", linestyle=':', marker='X', label='test')
    ax.legend(loc='upper left')
    
    text = "after plot in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()
    
    fig.clf()
    text = "after fig.clf() in loop "+str(index)
    print("\n"+text)
    uss = computing_memory()

print("-------------------")
plt.close(fig)
gc.collect()
text = "after gc.collect() in loop "+str(index)
print(text)
uss = computing_memory()
