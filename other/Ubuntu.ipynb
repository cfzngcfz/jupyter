# %% [markdown]
# # 通用部分

# %%
sudo apt update
sudo apt install lsb-release vim git wget tmux -y
# lsb_release -a

cd /mnt/d/github && chmod +x Miniconda3-py312_25.11.1-1-Linux-x86_64.sh
./Miniconda3-py312_25.11.1-1-Linux-x86_64.sh
echo "export PATH=~/miniconda3/bin:\$PATH" >> ~/.bashrc
source ~/.bashrc
# python -V
# conda -V

conda init
source ~/.bashrc

# %% [markdown]
# # ROS2
# https://docs.ros.org/en/humble/Installation/Ubuntu-Install-Debs.html#install-ros-2-packages

# %%
locale  # check for UTF-8

sudo apt update && sudo apt install locales
sudo locale-gen en_US en_US.UTF-8
sudo update-locale LC_ALL=en_US.UTF-8 LANG=en_US.UTF-8
export LANG=en_US.UTF-8

locale  # verify settings


sudo apt install software-properties-common
sudo add-apt-repository universe

sudo apt update && sudo apt install curl -y
export ROS_APT_SOURCE_VERSION=$(curl -s https://api.github.com/repos/ros-infrastructure/ros-apt-source/releases/latest | grep -F "tag_name" | awk -F\" '{print $4}')
curl -L -o /tmp/ros2-apt-source.deb "https://github.com/ros-infrastructure/ros-apt-source/releases/download/${ROS_APT_SOURCE_VERSION}/ros2-apt-source_${ROS_APT_SOURCE_VERSION}.$(. /etc/os-release && echo ${UBUNTU_CODENAME:-${VERSION_CODENAME}})_all.deb"
sudo dpkg -i /tmp/ros2-apt-source.deb

sudo apt update
sudo apt upgrade
sudo apt install ros-humble-ros-base -y
sudo apt install ros-humble-rosbag2-storage-mcap

> 6. Asia
> 70. shanghai

# 安装 ROS 2 的 Python API
# apt install -y libgtk2.0-dev pkg-config # cv2.error
sudo apt install ros-humble-rosbag2-py -y

# 设置环境变量
echo "source /opt/ros/humble/setup.bash" >> ~/.bashrc
source ~/.bashrc

conda create -y -n ros2 python=3.10
conda activate ros2

# colcon 安装
pip install numpy -i https://pypi.tuna.tsinghua.edu.cn/simple
pip install lark
pip install empy==3.3.4
pip3 install -U colcon-common-extensions

# lerobot 安装
cd ~
git clone https://github.com/huggingface/lerobot.git
cd ~/lerobot
conda install ffmpeg=7.1.1 -c conda-forge -y
pip install -e . -i https://pypi.tuna.tsinghua.edu.cn/simple
pip install -e .

# %% [markdown]
# # foxglove

# %%
# 数据端 Ubuntu install
sudo apt install ros-humble-foxglove-bridge
sudo apt install ros-humble-rosbag2-storage-mcap

# 本地可视化端
    # Windows 安装
    https://foxglove.dev/download

    # Ubuntu 安装
    wget https://get.foxglove.dev/desktop/latest/foxglove-studio-latest-linux-amd64.deb
    sudo apt install ./foxglove-studio-*.deb


# 使用
    # terminal 1
    ros2 bag play RB250714001_20251224164155801_RAW.mcap --loop

    # terminal 2
    ros2 run foxglove_bridge foxglove_bridge

    # Ubuntu 本地可视化端
    Dashboard (left) -> Open connection -> WebSocket URL -> ws://<ip address>:8765

    # wsl: 在 windows 本体可视化端下执行
    Dashboard (left) -> Open connection -> WebSocket URL -> ws://<ip address in wsl>:8765

    #多机
    ros2 run foxglove_bridge foxglove_bridge --ros-args -p port:=8766 port需要机器端和主机改成一致且不能是已经使用过的
